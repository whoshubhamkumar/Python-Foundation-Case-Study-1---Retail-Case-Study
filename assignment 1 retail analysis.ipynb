# %%
import pandas as pd

# %%
Customer = pd.read_csv("D:\DS\Assignment 4 Python\Python Foundation Case Study 1 - Retail Case Study\Customer.csv")
Customer
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
Product_hierarchy = pd.read_csv("D:\DS\Assignment 4 Python\Python Foundation Case Study 1 - Retail Case Study\prod_cat_info.csv")
Product_hierarchy
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
Transaction = pd.read_csv("D:\DS\Assignment 4 Python\Python Foundation Case Study 1 - Retail Case Study\Transactions.csv")
Transaction
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %% [markdown]
# ### 1. Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final. Ensure to keep all customers who have done transactions with us and select the join type accordingly.

# %%
Customer_Trans = pd.merge(left = Customer,right = Transaction, left_on = 'customer_Id', right_on = 'cust_id', how = 'inner', indicator = True)

# %%
Customer_Trans
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408  02-01-1970      M        4.0     87243835584   268408
# 1           268408  02-01-1970      M        4.0     16197868036   268408
# 2           268408  02-01-1970      M        4.0     16197868036   268408
# 3           268408  02-01-1970      M        4.0     28810141075   268408
# 4           268408  02-01-1970      M        4.0     64633435931   268408
# ...            ...         ...    ...        ...             ...      ...
# 23048       269626  27-12-1992      F        5.0     71369029396   269626
# 23049       269626  27-12-1992      F        5.0     94134051896   269626
# 23050       274308  29-12-1992      F        5.0     26208690928   274308
# 23051       274308  29-12-1992      F        5.0     57358822237   274308
# 23052       274308  29-12-1992      F        5.0     58160544337   274308
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
Customer_Final = pd.merge(left = Customer_Trans, right = Product_hierarchy, left_on = 'prod_cat_code', right_on = 'prod_cat_code', how = 'inner')

# %%
Customer_Final
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408  02-01-1970      M        4.0     87243835584   268408
# 1           268408  02-01-1970      M        4.0     87243835584   268408
# 2           268408  02-01-1970      M        4.0     87243835584   268408
# 3           268408  02-01-1970      M        4.0     87243835584   268408
# 4           268408  02-01-1970      M        4.0     87243835584   268408
# ...            ...         ...    ...        ...             ...      ...
# 99288       271772  17-12-1992      M        2.0     10440850091   271772
# 99289       271772  17-12-1992      M        2.0     10440850091   271772
# 99290       269626  27-12-1992      F        5.0     94134051896   269626
# 99291       269626  27-12-1992      F        5.0     94134051896   269626
# 99292       269626  27-12-1992      F        5.0     94134051896   269626
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %% [markdown]
# ### 2. Prepare a summary report for the merged data set.
# ### *2(a) Get the column names and their corresponding data types*

# %%
Customer_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99293 entries, 0 to 99292
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_Id        99293 non-null  int64
#  1   DOB                99293 non-null  object
#  2   Gender             99253 non-null  object
#  3   city_code          99257 non-null  float64
#  4   transaction_id     99293 non-null  int64
#  5   cust_id            99293 non-null  int64
#  6   tran_date          99293 non-null  object
#  7   prod_subcat_code   99293 non-null  int64
#  8   prod_cat_code      99293 non-null  int64
#  9   Qty                99293 non-null  int64
#  10  Rate               99293 non-null  int64
#  11  Tax                99293 non-null  float64
#  12  total_amt          99293 non-null  float64
#  13  Store_type         99293 non-null  object
#  14  _merge             99293 non-null  category
#  15  prod_cat           99293 non-null  object
# ...

# %% [markdown]
# ### Or

# %%
Customer_Final.dtypes
# Out:
# customer_Id             int64
# DOB                    object
# Gender                 object
# city_code             float64
# transaction_id          int64
# cust_id                 int64
# tran_date              object
# prod_subcat_code        int64
# prod_cat_code           int64
# Qty                     int64
# Rate                    int64
# Tax                   float64
# total_amt             float64
# Store_type             object
# _merge               category
# prod_cat               object
# prod_sub_cat_code       int64
# prod_subcat            object
# dtype: object

# %% [markdown]
# ### *2(b) Top/Bottom 10 observations*

# %%
Customer_Final.head(10)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0       268408  02-01-1970      M        4.0     87243835584   268408
# 1       268408  02-01-1970      M        4.0     87243835584   268408
# 2       268408  02-01-1970      M        4.0     87243835584   268408
# 3       268408  02-01-1970      M        4.0     87243835584   268408
# 4       268408  02-01-1970      M        4.0     87243835584   268408
# 5       268408  02-01-1970      M        4.0     87243835584   268408
# 6       268159  08-01-1970      F        8.0     65867401816   268159
# 7       268159  08-01-1970      F        8.0     65867401816   268159
# 8       268159  08-01-1970      F        8.0     65867401816   268159
# 9       268159  08-01-1970      F        8.0     65867401816   268159
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0  13-01-2014                 7              5    5   187   98.175   1033.175
# ...

# %%
Customer_Final.tail(10)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 99283       274618  09-12-1992      F        7.0     98631113719   274618
# 99284       268097  15-12-1992      F        7.0     71286190189   268097
# 99285       268097  15-12-1992      F        7.0     71286190189   268097
# 99286       268097  15-12-1992      F        7.0     71286190189   268097
# 99287       271772  17-12-1992      M        2.0     10440850091   271772
# 99288       271772  17-12-1992      M        2.0     10440850091   271772
# 99289       271772  17-12-1992      M        2.0     10440850091   271772
# 99290       269626  27-12-1992      F        5.0     94134051896   269626
# 99291       269626  27-12-1992      F        5.0     94134051896   269626
# 99292       269626  27-12-1992      F        5.0     94134051896   269626
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate     Tax  \
# 99283  19-04-2013                 3              1    2   721  151.41
# ...

# %% [markdown]
# ### 2(c). “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)

# %%
Customer_Final.describe()
# Out:
#          customer_Id     city_code  transaction_id        cust_id  \
# count   99293.000000  99257.000000    9.929300e+04   99293.000000
# mean   271030.010635      5.467221    5.007320e+10  271030.010635
# std      2429.333624      2.859343    2.899361e+10    2429.333624
# min    266783.000000      1.000000    3.268991e+06  266783.000000
# 25%    268956.000000      3.000000    2.492150e+10  268956.000000
# 50%    270982.000000      5.000000    5.011083e+10  270982.000000
# 75%    273120.000000      8.000000    7.528121e+10  273120.000000
# max    275265.000000     10.000000    9.998755e+10  275265.000000
#
#        prod_subcat_code  prod_cat_code           Qty          Rate  \
# count      99293.000000   99293.000000  99293.000000  99293.000000
# mean           6.796894       4.003243      2.438017    637.919884
# std            3.609439       1.563991      2.260726    621.576326
# min            1.000000       1.000000     -5.000000  -1499.000000
# ...

# %%
import numpy as np
Data_min = Customer_Final['total_amt'].min()
Data_max = Customer_Final['total_amt'].max()
Data_q1  = np.percentile(Customer_Final.total_amt,25)
median  = np.percentile(Customer_Final.total_amt,50)
Data_q3  = np.percentile(Customer_Final.total_amt,75)
print('Min =',Data_min)
print('Max =',Data_max)
print('Median =',median)
print('Q1 =',Data_q1)
print('Q3 =',Data_q3)
# Out:
# Min = -8270.925
# Max = 8287.5
# Median = 1761.37
# Q1 = 762.45
# Q3 = 3585.725

# %% [markdown]
# ### 2(d). Frequency tables for all the categorical variables

# %%
freq_table = pd.crosstab(index = Customer_Final.Gender, columns = Customer_Final.Store_type)
freq_table
# Out:
# Store_type  Flagship store    MBR  TeleShop  e-Shop
# Gender
# F                     9767   9687      9159   19589
# M                    10047  10278     10142   20584

# %%
freq_table = pd.crosstab(index = Customer_Final.Gender, columns = Customer_Final.prod_subcat)
freq_table
# Out:
# prod_subcat  Academic  Audio and video  Bath  Cameras  Children  Comics  \
# Gender
# F                2949             2328  1994     2328      2949    2949
# M                3116             2570  2134     2570      3116    3116
#
# prod_subcat  Computers   DIY  Fiction  Furnishing  Kids  Kitchen  Mens  \
# Gender
# F                 2328  2949     2949        1994  2968     1994  3962
# M                 2570  3116     3116        2134  2987     2134  3991
#
# prod_subcat  Mobiles  Non-Fiction  Personal Appliances  Tools  Women
# Gender
# F               2328         2949                 2328   1994   3962
# M               2570         3116                 2570   2134   3991

# %%
freq_table = pd.crosstab(index = Customer_Final.Gender, columns = Customer_Final.prod_cat)
freq_table
# Out:
# prod_cat  Bags  Books  Clothing  Electronics  Footwear  Home and kitchen
# Gender
# F         1988  17694      4317        11640      4587              7976
# M         2008  18696      4554        12850      4407              8536

# %% [markdown]
# ### 3. Generate histograms for all continuous variables and frequency bars for categorical variables.
#
# ### 3.(1)Tax (continuous variable)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.grid()
Tax = Customer_Final['Tax']
plt.hist(Tax,color=['blue'])
plt.xlabel('tax')
plt.ylabel('Frequency')
plt.title('Frequency dist. of tax')
plt.show()

# %% [markdown]
# ### 3.(2) Total amount (continuous variable)

# %%
Total_Amt = Customer_Final['total_amt']
plt.hist(Total_Amt,color = 'Blue')
plt.grid()
plt.xlabel('Total amount')
plt.ylabel('Frequency')
plt.title('Frequency dist. of total amount')
plt.show()

# %% [markdown]
# ### 3.(3)Rate (continuous variable)

# %%
Customer_Final['Rate'].plot(kind = 'hist', color= 'blue')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### 3.(3) Gender (Categorical variable)

# %%
Customer_Final['Gender'].value_counts().plot(kind = 'barh', color = 'yellow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3.(4)  Store type (Categorical variable)

# %%
Customer_Final['Store_type'].value_counts().plot(kind = 'barh', color = 'yellow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3.(5)  Product category (Categorical variable)

# %%
Customer_Final['prod_cat'].value_counts().plot(kind = 'barh', color = 'yellow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3.(6)  Product sub-category (Categorical variable)

# %%
Customer_Final['prod_subcat'].value_counts().plot(kind = 'barh', color = 'yellow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. Calculate the following information using the merged dataset :
#  ### *a. Time period of the available transaction data*

# %%
# Convert DOB type to datetime object
Customer_Final.DOB=pd.to_datetime(Customer_Final.DOB,format="%d-%m-%Y")

# %%
# Convert transaction date type to datetime object
def convertDateTime(x):
    x=x.replace('/','-')
    x=pd.to_datetime(x,format='%d-%m-%Y')
    return x

# %%
Customer_Final.tran_date=Customer_Final.tran_date.apply(lambda x: convertDateTime(x))

# %%
Max_Available_Date = Customer_Final.tran_date.max()

# %%
Max_Available_Date
# Out:
# Timestamp('2014-02-28 00:00:00')

# %%
Min_Available_Date = Customer_Final.tran_date.min()

# %%
Min_Available_Date
# Out:
# Timestamp('2011-01-25 00:00:00')

# %%
(Max_Available_Date - Min_Available_Date).days
# Out:
# 1130

# %% [markdown]
# ### *4.(b)Count of transactions where the total amount of transaction was negative*

# %%
# Count of transactions where the total amount of transaction was negative
df = Customer_Final['total_amt']
count2 = Customer_Final.loc[(df<0),['total_amt']].count()
count2
# Out:
# total_amt    9294
# dtype: int64

# %% [markdown]
# ### 5. Analyze which product categories are more popular among females vs male customers.

# %%
# Popular among Male
M = Customer_Final.loc[Customer_Final['Gender']=='M']
group_prod = M.groupby(['prod_cat'])['total_amt'].sum()
popular_M = group_prod.nlargest(1)
display('The most popular product category in Male customers is : ',popular_M)

# Popular among Female
F = Customer_Final.loc[Customer_Final['Gender']=='F']
group_prod1 = F.groupby(['prod_cat'])['total_amt'].sum()
popular_F = group_prod1.nlargest(1)
display('The most popular product category in Female customers is : ',popular_F)
# Out:
# 'The most popular product category in Male customers is : '
# prod_cat
# Books    39875836.65
# Name: total_amt, dtype: float64
# 'The most popular product category in Female customers is : '
# prod_cat
# Books    36988153.41
# Name: total_amt, dtype: float64

# %% [markdown]
# ### 6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
max_cust = Customer['city_code'].value_counts()
t = max_cust.nlargest(1)

display("City code which has Maximum customers is : ",t)
# Out:
# 'City code which has Maximum customers is : '
# 3.0    595
# Name: city_code, dtype: int64

# %%
#percentage of customers from city code 3
tot_customer = Customer['customer_Id'].count()
percent = round((595/tot_customer)*100,2)
print("Percentage of customers from the city code 3 is {}% : ".format(percent))
# Out:
# Percentage of customers from the city code 3 is 10.54% :

# %% [raw]
# Hence City Code 3 have max no of customers.

# %% [markdown]
# ### 7. Which store type sells the maximum products by value and by quantity?

# %%
ProductValue=Customer_Final.groupby('Store_type')[['Qty','total_amt']].agg({'Qty':'sum','total_amt':'sum'}).reset_index()

# %%
ProductValue.sort_values(['Qty','total_amt'],ascending=False)
# Out:
#        Store_type    Qty     total_amt
# 3          e-Shop  98447  8.591575e+07
# 1             MBR  48285  4.170033e+07
# 0  Flagship store  48007  4.188397e+07
# 2        TeleShop  47339  4.046656e+07

# %% [raw]
# Hence, Store Type e-shop sells maximun products by total amount(value) and by quantity.

# %% [markdown]
# ### 8. What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
df = pd.DataFrame(Customer_Final)
tf = df[df.prod_cat.isin(['Electronics','Clothing']) & (df.Store_type == 'Flagship store')]
total = tf.total_amt.sum()
print('Total amount earned',total)
# Out:
# Total amount earned 14658949.89

# %% [markdown]
# ### 9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
tf1 = df[(df.Gender == 'M') & (df.prod_cat == 'Electronics')]
total = tf1.total_amt.sum()
print('Total amount earned',total)
# Out:
# Total amount earned 28515547.125

# %% [markdown]
# ### Q10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
df1 = df[(df.total_amt > 0)]
ts = df1.transaction_id.nunique()
print('Total customers having more than 10 unique transactions are - ',ts)
# Out:
# Total customers having more than 10 unique transactions are -  20876

# %% [markdown]
# ### Q11. For all customers aged between 25 - 35, find out:
# ### *a. What was the total amount spent for “Electronics” and “Books” product categories*

# %%
curr_year = pd.to_datetime('today').year
dob_year = pd.DatetimeIndex(df['DOB']).year                     #extract year from DOB
x = dob_year-100                                                # for the years which belongs to 60's
v = curr_year - x
y = curr_year - dob_year
df['age'] = (np.where(dob_year > curr_year,v,y))
df
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408 1970-01-02      M        4.0     87243835584   268408
# 1           268408 1970-01-02      M        4.0     87243835584   268408
# 2           268408 1970-01-02      M        4.0     87243835584   268408
# 3           268408 1970-01-02      M        4.0     87243835584   268408
# 4           268408 1970-01-02      M        4.0     87243835584   268408
# ...            ...        ...    ...        ...             ...      ...
# 99288       271772 1992-12-17      M        2.0     10440850091   271772
# 99289       271772 1992-12-17      M        2.0     10440850091   271772
# 99290       269626 1992-12-27      F        5.0     94134051896   269626
# 99291       269626 1992-12-27      F        5.0     94134051896   269626
# 99292       269626 1992-12-27      F        5.0     94134051896   269626
#
#        tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
total = df.loc[((df.age >25) & (df.age <35)) & ((df.prod_cat=='Books') | (df.prod_cat=='Electronics'))]['total_amt'].sum()
print('Total amount earned',total)
# Out:
# Total amount earned 27367446.599999998

# %% [markdown]
# ### *b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?*

# %%
Customer_Final['tran_date'] = pd.to_datetime(Customer_Final['tran_date'])

t_date = Customer_Final[(Customer_Final['tran_date'] > '2014-01-01') & (Customer_Final['tran_date'] < '2014-03-01')]
total_amount = t_date.total_amt.sum()
print('Total amount spent by the customer - ',total_amount)
# Out:
# Total amount spent by the customer -  9343573.915

# %% [markdown]
# ### End of retail analysis assignment
